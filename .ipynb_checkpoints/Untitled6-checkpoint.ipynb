# %%
import pandas as pd

# %%
bicycle = pd.read_excel('AccidentesBicicletas_2018.xlsx')
bicycle
# Out:
#          FECHA     RANGO HORARIO DIA SEMANA                        DISTRITO  \
# 0   2018-01-01  DE 13:00 A 13:59      LUNES  ARGANZUELA
# 1   2018-01-01  DE 15:00 A 15:59      LUNES  CENTRO
# 2   2018-01-02  DE 12:00 A 12:59     MARTES  SALAMANCA
# 3   2018-01-03  DE 13:00 A 13:59  MIERCOLES  SALAMANCA
# 4   2018-01-03  DE 15:00 A 15:59  MIERCOLES  CIUDAD LINEAL
# ..         ...               ...        ...                             ...
# 695 2018-12-25  DE 12:00 A 12:59     MARTES  FUENCARRAL-EL PARDO
# 696 2018-12-28    DE 9:00 A 9:59    VIERNES  CHAMARTIN
# 697 2018-12-28  DE 14:00 A 14:59    VIERNES  CENTRO
# 698 2018-12-29  DE 10:00 A 10:59     SABADO  TETUAN
# 699 2018-12-29  DE 19:00 A 19:59     SABADO  CHAMBERI
#
#                                        LUGAR ACCIDENTE   Nº    Nº PARTE  \
# 0    CALLE DE ANCORA - PASEO DE LAS DELICIAS       ...    0     2018/25
# 1    CALLE DE ALCALA NUM                           ...   44     2018/76
# ...

# %%
bicis = pd.read_excel('bicis_usos_acumulado.xls')
bicis
# Out:
#             DIA  Usos bicis abono anual   Usos bicis abono ocasional   \
# 0    2014-06-23                       20                           79
# 1    2014-06-24                       24                           48
# 2    2014-06-25                      105                           14
# 3    2014-06-26                      120                           15
# 4    2014-06-27                      131                           18
# ...         ...                      ...                          ...
# 2652 2021-09-26                     8810                           62
# 2653 2021-09-27                    10769                           15
# 2654 2021-09-28                    11519                           27
# 2655 2021-09-29                    12335                           26
# 2656 2021-09-30                    12250                           20
#
#       Usos bicis total  Unnamed: 4  Usos abono anual acumulado  \
# ...

# %%
abono = pd.read_excel('bicis_usuarios_abonos.xls')
abono
# Out:
#             Día  Altas nuevos usuarios activos ab. anual sin ttp día  \
# 0    2014-06-23                                                 47
# 1    2014-06-24                                                 21
# 2    2014-06-25                                                193
# 3    2014-06-26                                                150
# 4    2014-06-27                                                185
# ...         ...                                                ...
# 2652 2021-09-26                                                 21
# 2653 2021-09-27                                                 18
# 2654 2021-09-28                                                -10
# 2655 2021-09-29                                                -55
# 2656 2021-09-30                                                -11
#
#       Altas nuevos usuarios activos ab. anual con ttp día  \
# 0                                                    44
# ...

# %%
total_accidentes = pd.read_excel('2018_Accidentalidad.xlsx')
total_accidentes
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8354c9df593e> in <module>
# ----> 1 total_accidentes = pd.read_excel('2018_Accidentalidad.xlsx')
#       2 total_accidentes
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     342
#     343     try:
# ...
